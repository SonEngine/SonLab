# %%
import numpy as np

# %%
import torch

print(torch.cuda.is_available())
print(torch.__version__)
# Out:
# True
# 2.4.0+cu121

# %%
import torch
import pytorch3d
print('torch', torch.__version__, 'cuda', torch.version.cuda, torch.cuda.is_available())
print('pytorch3d import OK')
# Out:
# torch 2.4.0+cu121 cuda 12.1 True
# pytorch3d import OK
